# %% [markdown]
# # Vivo - AIOps Machine Learning Engineering Challenge
# Olá candidatxs. Agradecemos o interesse pela vaga de [Engenharia de Machine Learning na área de AIOps da Telefónica Brasil S.A (Vivo)](https://vivo.gupy.io/jobs/180473).
#
# Esse notebook compreende a Data Challenge voltada à vaga de Engenharia de Machine Learning desenvolvido pela equipe de AIOps. O objetivo deste desafio é entender um pouco melhor como vocês pensam em relação à atuação de um(a) Engenheiro(a) de Machine Learning em projetos de Inteligência Artificial corporativos e como raciocinam frente a problemas parecidos com o que vivenciamos no dia-a-dia da área. Com isso, este desafio não é uma competição e não existem respostas erradas. O que vale é a resolução de problemas baseada em dados e como vocês comunicam suas respostas.
#
# Por favor, leiam com atenção as propostas de cada uma das perguntas e se atentem para a as **Sugestões** e **Requerimentos** deste desafio.
#
# Vocês terão **três dias** para resolver os problemas aqui propostos, até o **23:59 do terceiro dia** após o envio do e-mail com o desafio. Se houver qualquer problema com o teste que atrapalhe o prazo de entrega, por favor comunique o responsável pelo teste, Mateus Gomes, no e-mail mateus.pgomes@telefonica.com.
#
# ## O que é AIOps na Vivo?
# A área de AIOps da Vivo tem como objetivo melhorar a qualidade do serviço da Operação de TI (ITOps), agregando o que chamamos de Inteligência Operacional à companhia. Com isso, desenvolvemos soluções de dados para entregar insights de alto valor para a Operação, seja para tomar uma decisão, um direcionamento durante troubleshooting ou para entender tendências no ambiente e sistemas de TI.
#
# A Operação de TI e os sistemas que a mesma governa geram dados de alta variabilidade, variedade e volume. Alguns dos tipos de dados envolvidos são:
#
# - Logs de Aplicações;
# - Traps SNMP;
# - Telemetria/Alertas de ferramentas de monitoração diversas;
# - Incidentes registrados no ITSM;
# - Métricas do negócio e diversos KPIs;
#
# Apesar de gerarmos tantos dados e de tantas fontes diferentes, tendo em vista a alta complexidade do ambiente, a Operação tem dificuldade de interpretar e extrair insights relevantes destes dados rápido o suficiente.
#
# ## Contexto dos clientes internos e usuários
# A equipe de AIOps entra nesse cenário como fornecedora de insights e produtos para melhorar a qualidade das decisões, monitorações e sistemas da Vivo, a fim de tornar a Operação inteligente e proativa.
#
# Neste escopo de atuação, temos três clientes importantes:
# - CIM: o command center da operação, que faz a gestão dos incidentes e monitorações alto-nível do ambiente. O perfil destes profissionais é de N1 de atendimento, menos técnico que os níveis N2/N3;
# - PCPs/Sustentação: profissionais de cunho MAIS técnico-operacional que fazem a gestão dos sistemas da companhia. Eles respondem os chamados de incidentes, fazem a gestão do ambiente produtivo dos seus respectivos sistemas, além de corrigirem problemas de performance e abrirem reports de bugs para os Desenvolvedores. São equivalentes ao atendimento N2/N3 da companhia;
# - Executivos: tomadores de decisão da empresa, que precisam de dados para saber o que fazer;
#
# ## Requerimentos para responder este desafio
# 1. Só deverão ser utilizados para compor as respostas deste desafio os dados providenciados. Os dados aqui disponibilizados são fictícios e criados para simular situações reais de AIOps;
# 2. Qualquer referência utilizada para responder esse desafio deve ser listada na seção **Referências** desse notebook. Plágio não será aceito em hipótese alguma;
# 3. As respostas para as perguntas feitas aqui deverão ser respondidas em detalhe, a fim de capturar o seu processo de resolução de problemas;
# 4. As respostas em código para as perguntas aqui colocadas deverão ser escritas utilizando, idealmente, Python, a fim de ser reproduzível no ambiente do **Google Colab**.
#     - Caso não respondam essa atividade utilizando alguma linguagem de programação nativa do ambiente de desenvolvimento referido acima, deverão enviar o código fonte junto a uma resposta para um dos e-mails de contato dispostos na seção **Contatos**, ou deve ser enviado um link do repositório contendo a resposta no **GitHub**;
#     - Todo código apresentado deve ser reproduzível. Portanto, se o código empregado para a solução não for reproduzível diretamente no ambiente de desenvolvimento **Google Colab**, será necessário providenciar os requisitos de ambiente usados para desenvolver a resposta;
# 5. É muito importante para nós que a resolução de problemas sejam orientadas por dados. Se vocês acreditam que suas respostas funcionam, precisamos de informações para averiguar isso com dados e fatos. Respostas como "por experiência" não serão consideradas suficientes;
# 6. Não é necessário responder todas as perguntas, porém os encorajamos a tentar responder todas. Ao menos uma pergunta, porém, deve ser respondida;

# %% [markdown]
# ## Setup dos dados
# Por favor, execute as linhas de código a seguir sem mudar nada. Elas farão o download dos dados para este desafio e os colocarão em um diretório chamado `datasets`. Imagens relevantes para este desafio também serão baixadas e colocadas no diretório `img`.

# %%
# # criando o diretório:
# !echo 'Criando o diretório para os dados e imagens'
# !mkdir ./datasets
# !mkdir ./img

# # Baixando as imagens
# !echo 'Baixando imagens'
# !wget https://www.dropbox.com/s/i95umy72v37ayqf/estrutura_coleta.png?dl=0 -O ./img/estrutura_coleta.png

# # baixando dados para questão 1:
# !echo 'Baixando dados para questão 1'
# !wget https://www.dropbox.com/s/9h0kb34cori1bna/model_predictions.csv?dl=0 -O ./datasets/model_predictions.csv
    
# # baixando dados para questão 2:
# !echo 'Baixando dados para questão 2'
# !wget https://www.dropbox.com/s/l5wnklpl2xdy507/requests.json?dl=0 -O ./datasets/requests.json
    
# # baixando dados para questão 3:
# !echo 'Baixando dados para questão 3'
# !wget https://www.dropbox.com/s/82p5k4zq9eymg03/process_change.csv?dl=0 -O ./datasets/process_change.csv

# # baixando dados para questão 4:
# !echo 'Baixando dados para questão 4'
# !wget https://www.dropbox.com/s/z4mx9ynul6d7431/access.log?dl=0 -O ./datasets/access.log
# Out:
# Criando o diretório para os dados e imagens
# mkdir: cannot create directory ‘./datasets’: File exists
# mkdir: cannot create directory ‘./img’: File exists
# Baixando imagens
# --2020-03-30 02:18:48--  https://www.dropbox.com/s/i95umy72v37ayqf/estrutura_coleta.png?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/i95umy72v37ayqf/estrutura_coleta.png [following]
# --2020-03-30 02:18:48--  https://www.dropbox.com/s/raw/i95umy72v37ayqf/estrutura_coleta.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Questão 1: Caixas pretas
# Você recebeu um e-mail de um analista da equipe de PCP que o "modelo de previsão em redes neurais" de uma ferramenta Z não parece estar funcionando muito bem. Segundo o analista, os resultados são muito variáveis e pouco acurados. Ao analisar a ferramenta, um colega de AIOps verifica que não há documentação pública existente em relação ao modelo aplicado, já que a ferramenta é uma verdadeira caixa preta.
#
# O colega de equipe então extrai um resultado da base de treinamento usada para construir esse modelo de regressão e as predições originais do modelo para aquele dataset no momento inicial de configuração. Considere que esse dataset é representativo da tarefa em que esse modelo seria realmente aplicado e, no mundo real, há muito mais registros no dataset.
#
# O dataset foi disponibilizado no arquivo `model_predictions.csv` para que você possa analisar o que está acontecendo e consiste nos seguinte formato:
#
# - `timestamp` é o timestamp do registro, no formato `[ano-mês-dia hora:minuto:segundo]`
# - `values` são os valores de cada registro.
# - `predictions` são as predições realizadas para o modelo no memso período.
#
# ### Perguntas:
# - **(a)** O que pode estar acontecendo com o modelo?
# - **(b)** Por quais motivos esse modelo poderia estar performando mal no cenário produtivo?
# - **(c)** Como você explicaria pros seus colegas de AIOps o problema com o modelo? E para os gerentes?
# - **(d)** Que modelo você implementaria em substituição ao modelo da ferramenta Z?
# - **(e)** Por favor, demonstre a implementação do modelo sugerido.

# %%
# código para questão 1:
import pandas as pd

# Função de parser da data do arquivo csv
dateparse_q1 = lambda date: pd.datetime.strptime(date, '%Y-%m-%d %H:%M')

# load dos dados
# parse das datas em tempo de load do arquivo é mais rapido
data = pd.read_csv('datasets/model_predictions.csv', 
                   sep=',', 
                   header=0,
                   low_memory=False, 
                   encoding='utf-8',
                   parse_dates=['timestamp'], 
                   date_parser=dateparse_q1)

# verificando os types de cada coluna
data.dtypes
# Out:
# timestamp      datetime64[ns]
# values                float64
# predictions           float64
# dtype: object

# %%
# visualização dos dados
data.head()
# Out:
#             timestamp     values  predictions
# 0 2020-01-01 00:00:00   9.413109    10.205871
# 1 2020-01-01 00:01:00  26.754913    17.338156
# 2 2020-01-01 00:02:00  33.934173    31.446670
# 3 2020-01-01 00:03:00   1.867156    -2.539267
# 4 2020-01-01 00:04:00 -14.750140   -12.143018

# %%
# existem dados nulos na base?
data.isna().sum()
# Out:
# timestamp      0
# values         0
# predictions    0
# dtype: int64

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
# calculando RMSE
from sklearn.metrics import mean_squared_error

# verificando taxa de erro entre treino e teste, utilizando RMSE
mean_squared_error(y_true=data["values"], y_pred=data["predictions"], squared=False)
# Out:
# 4.846123292619919

# %% [markdown]
# Considerando que o RMSE deve ser, idealmente, quanto mais próximo de zero possível, podemos ver que o modelo não uma taxa de erro tão elevada para afirmar que o modelo está performando mal.
#
# Os dados aparentam ser de uma Timeseries. Com isso em mente, vamos verificar os valores originais com os preditos pelo do tempo, de uma forma gráfica.

# %%
# distribuições através do tempo

# Avaliação
def plot_dispersao(df, index=False, field='', **kwargs):
  """
  Metodo para exibição de gráfico para comparar o valor real com o valor predito de uma Regressão
  :param df: DataFrame para exibição
  :param index: Informa a necessidade de setar o indice como timestamp
  :param field: Campo que possui a informação de data, ignorado caso index seja False
  """
  # %matplotlib inline
  import matplotlib.pyplot as plt
  import seaborn as sns

  if index:
    df.set_index(field, inplace=True)

  # setando tamanho da imagem
  plt.rcParams.update({'figure.figsize': (25, 9), 'figure.dpi': 120})

  # exibindo os dados, com os dados visiveis através de bolinhas
  if kwargs.get('x') and kwargs.get('y'):
    df.plot.line(x=kwargs.get('x'), y=kwargs.get('y'))
  else:
    df.plot.line(marker='o')


# criando uma copia dos dados e setando o campo timestamp como index do DF
data_manipulado = data.copy()

# Visualização
plot_dispersao(data_manipulado, index=True, field='timestamp')

# %% [markdown]
# Podemos analisar que o modelo parece se comportar bem em relação os dados de treino e teste.
#
# Com os dados em mãos, podemos inferir que o modelo esteja com overfitting.

# %% [markdown]
# # Respostas:
# ####(a) O que pode estar acontecendo com o modelo?
#  - Analisando o erro dos dados (RMSE), que nos informa a média de distancia entre o real vs predito, e com a ajuda da visualização gráfica dos dados, é possível que o modelo esteja com Overfitting.
#
# ####(b) Por quais motivos esse modelo poderia estar performando mal no cenário
# produtivo?
#  -  Assumindo que o modelo esteja com Overfitting, o modelo não está generalizando o suficiente para conseguir uma performance adequada com dados não visto durante o treinamento. Isso pode acontecer quando existe pouca quantidade de dados disponível ou quando a separação entre treino e teste não é feita adequadamente, por exemplo, não utilizando técnicas de estratificação, KFold, entre outras.
#
# ####(c) Como você explicaria pros seus colegas de AIOps o problema com o modelo? E para os gerentes?
#  - Para o time de AIOps, explicaria que pelo modelo performar muito bem com os dados de teste, e apresentando um cenário oposto com dados produtivos, provavelmente o modelo foi treinado com poucos dados e/ou sem técnicas de estratificação, o que resultou em um cenário de Overfitting.
#  Para os gerentes, explicaria que o modelo não foi treinado com dados o suficiente para conseguir resolver casos não conhecidos pós-produção.
#
# ####(d) Que modelo você implementaria em substituição ao modelo da ferramenta Z?
#  -  Particularmente considero que Redes Neurais são custosas para treinamento e, se tratando de um modelo BlackBox, pode ser que a arquitetura por trás não seja a ideal para o problema.
#  Com os dados disponíveis, abriria os dados utilizando técnicas de pivot para não adicionar ordem de grandeza entre os valores, para adicionar sasonalidade, já que temos uma situação de TimeSeries, e na sequencia, faria testes com uma Regressão Linear que são computacionalmente menos custosas. Caso não performe bem, olharia para outros modelos como Árvore de Regressão, ARIMA e em último caso olharia para DeepLearning, com redes LSTM.
#
# ####(e) Por favor, demonstre a implementação do modelo sugerido.
# -  Código na celula abaixo 🙂

# %%
# Modelo de TimeSeries

# Load dos dados
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Função de parser da data do arquivo csv
dateparse_q1 = lambda date: pd.datetime.strptime(date, '%Y-%m-%d %H:%M')

# load dos dados
# parse das datas em tempo de load do arquivo é mais rapido
data = pd.read_csv('datasets/model_predictions.csv', 
                   sep=',', 
                   header=0,
                   low_memory=False, 
                   encoding='utf-8',
                   parse_dates=['timestamp'], 
                   date_parser=dateparse_q1)

# Preparação dos dados
# Copia para não precisar fazer o load novamente do arquivo
data_modelo = data.copy()

# Abrindo informações de data
data_modelo["dia_semana"] = data["timestamp"].dt.weekday_name
data_modelo["mes"] = data["timestamp"].dt.month_name()
data_modelo["hora"] = data["timestamp"].dt.hour
data_modelo["minuto"] = data["timestamp"].dt.minute

# Pivot das informações
pivot = pd.get_dummies(data_modelo[["dia_semana","mes","hora","minuto"]].astype(str))
data_modelo = pd.concat([data_modelo, pivot], axis=1)

# Removendo columas não mais necessárias
data_modelo.drop(["timestamp", "dia_semana", "mes", "hora", "minuto", "predictions"], inplace=True, axis=1)

# separação dos dados
# vamos utilizar 75-25, treino-teste
treino_x = data_modelo.loc[:74].drop(["values"], axis=1)
validacao_x = data_modelo.loc[75:].drop(["values"], axis=1)
treino_y = data_modelo.loc[:74, ["values"]]
validacao_y = data_modelo.loc[75:, ["values"]]


# validando se a divisão foi correta
assert len(data_modelo) == treino_x.shape[0] + validacao_x.shape[0], "Valores podem estar repetidos entre os datasets de Treino e Validação"

# %%
# Modelagem
from sklearn.model_selection import KFold, validation_curve
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.linear_model import LinearRegression


# Cross Validation
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold
fold = KFold(n_splits=10, shuffle=True, random_state=10)

# modelo
# normalizando os dados para manter a escala, utilizando todas as CPUs
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linearregression#sklearn.linear_model.LinearRegression
modelo = LinearRegression(normalize=True, n_jobs=-1)
teste = 0

# iniciando treino
for treino_index, teste_index in fold.split(treino_x, treino_y):
  teste +=1
  x_treino, x_teste = treino_x.loc[treino_index], treino_x.loc[teste_index]
  y_treino, y_teste = treino_y.loc[treino_index], treino_y.loc[teste_index]

  # treinando o modelo, convertendo os valores para array
  modelo.fit(X=x_treino.values, y=y_treino.values)

  # convertendo teste para array
  predicao = modelo.predict(X=x_teste)

  # Informando o RMSE na tela
  print('Fold {0} - RMSE: {1}'.format(teste, mean_squared_error(y_true=y_teste, y_pred=predicao, squared=False)))
# Out:
# Fold 1 - RMSE: 1316479600866149.2
# Fold 2 - RMSE: 12126660032970.623
# Fold 3 - RMSE: 1256342449582643.5
# Fold 4 - RMSE: 108130580076945.55
# Fold 5 - RMSE: 1892046325633246.0
# Fold 6 - RMSE: 234716078282223.4
# Fold 7 - RMSE: 272710878233295.62
# Fold 8 - RMSE: 2527463951715589.0
# Fold 9 - RMSE: 4385600191710008.5
# Fold 10 - RMSE: 537105052112804.25

# %%
# Se Regressão Linear fosse a mais ideal para o problema, com uma quantidade maior de dados
modelo_final = LinearRegression(normalize=True, n_jobs=-1).fit(treino_x.values, treino_y.values)
predict_final = modelo.predict(validacao_x)
print('RMSE Final: {0}'.format(mean_squared_error(y_true=validacao_y, y_pred=predict_final, squared=False)))
# Out:
# RMSE Final: 284209279161377.7

# %% [markdown]
# ## Questão 2: Detecção de Anomalias
# As equipes de Redes e Sustentação do sistema Z contataram a equipe de AIOps reportando problemas em relação à disponibilidade de um serviço específico.
#
# Em momentos críticos para a empresa, o sistema Z tem quedas que torna o serviço praticamente inútil. Os analistas têm bastante dificuldade em identificar esse momentos rápido o suficiente e a olho nu, e tais problemas podem trazer consequências inesperadas tempos depois.
#
# A forma como este processo de coleta de métricas e logs é orquestrado hoje é ilustrado no seguinte diagrama:
#
# ![Arquitetura lógica do processo de ingestão de dados do sistema Z](img/estrutura_coleta.png "Arquitetura lógica do processo de ingestão de dados do sistema Z")
#
# Um colega da equipe de AIOps providenciou um arquivo chamado `requests.json` contendo um monitoramento da quantidade de requests de sucesso de um dos principais serviços deste sistema. O dicionário de dados abaixo representa a informação disponível:
#
# - `timestamp` é o timestamp do registro, no formato `[ano-mês-dia hora:minuto:segundo]`. No arquivo .json, ele está quebrado em seus metadados, como, por exemplo, `day`, `dayofyear`, etc.
#
# - `request_counts` é a quantidade de requests de sucesso, normalizado (entre 0 a 1). É um valor float64.
#
# ### Perguntas:
# - **(a)** Que tipo de modelo ou algoritmo pode ser construído para ajudar as equipes responsáveis pelo sistema Z a detectarem essas anomalias mais rapidamente?
# - **(b)** Desenvolva o modelo sugerido.
# - **(b)** Como você serviria esse modelo em um processo de streaming?
# - **(c)** Como você reportaria ou demonstraria os resultados do seu modelo?
# - **(d)** Que produto de dados pode ser desenvolvido para que as equipes que lhe apresentaram o problema mitiguem possa agir mais rápido? Por favor ilustre seus resultados.

# %% [markdown]
# ### Respostas:
# **(a)** Que tipo de modelo ou algoritmo pode ser construído para ajudar as equipes responsáveis pelo sistema Z a detectarem essas anomalias mais rapidamente?
#  -  Podemos utilizar um modelo de classificação baseado no número normalizado de requests para realizar uma categorização de possível falha. Com isso, e um pipeline de processamento de dados que consuma o modelo, podemos alertar os responsáveis caso ocorra alguma identificação de problema pelo modelo.
#
# **(b)** Desenvolva o modelo sugerido.
#  -  Código abaixo.
#
# **(c)** Como você serviria esse modelo em um processo de streaming?
#  -  Através de uma imagem Docker hospedado em algum ambiente Kubernetes. Com isso em mãos, seria possível disponibilizar uma API para consulta e/ou coleta de dados para classificação online.
#
# **(d)** Como você reportaria ou demonstraria os resultados do seu modelo?
#  -  Considerando que estamos com um modelo de classificação, o ideal seria coletar um feedback do times responsável, informando se tivemos alarme em caso de falha, ou não. Com esses dados, poderíamos cruzar os dados com o que foi de fato predito pelo modelo e fazer uma matriz de confusão para avaliar os dados em produção.
#
# **(e)** Que produto de dados pode ser desenvolvido para que as equipes que lhe apresentaram o problema mitiguem possa agir mais rápido? Por favor ilustre seus resultados.
#  -  Os dados poderiam ser coletados de forma pro-ativa no Elasticsearch, processados e consultados por nossa API, que em caso de possível falha, avisa os responsável pelo serviço que uma possível falha pode estar a caminho.

# %%
# Grafico de Curva de Aprendizado * com alterações
# Reference: Scikit-Learn Documentation
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html
# Description: Plot learning curve performance of a model, considering Stratified folds

from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, 
                        title, 
                        X, 
                        y, 
                        ylim=None, 
                        cv=None,
                        n_jobs=None, 
                        train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    # Change
    fig=plt.figure()
    
    plt.title(title)
    
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_sizes, train_scores, test_scores = learning_curve(
                                                            estimator, X, y, cv=cv, scoring=scorer,
                                                            n_jobs=n_jobs, train_sizes=train_sizes)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
    
    # Modification - Duan
    # Show scores as dots
    ax = fig.add_subplot(111)
    x = train_sizes
    y = [round(score, 3) for score in test_scores_mean]
    
    for i,j in zip(x,y):
        ax.annotate(str(j),xy=(i,j), color="g")
    
    y = [round(score, 3) for score in train_scores_mean]
    
    for i,j in zip(x,y):
        ax.annotate(str(j),xy=(i,j), color="r")
        
    # Continue

    plt.legend(loc="best")
    
    return plt

# %%
# Grafico de Matriz de Confusão
# Reference: Scikit-Learn Documentation
# Link: https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
# Descrption: Plot graphical Confusion Matrix
import itertools  

def plot_confusion_matrix(cm, 
                          classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# código para questão 2:
# Imports
import json
from pandas.io.json import json_normalize
from datetime import datetime

# Abrindo o arquivo, evitando que o IO fique aberto pós utilização
with open('datasets/requests.json') as arquivo:
  json_data = arquivo.read()
  data_q2 = json.loads(json_data)

# Loop para adicionar a informação de request_counts dentro do dicionário pai
for index, value in enumerate(data_q2):
  data_q2[index][0]["request_counts"] = data_q2[index][1]
  data_q2[index] = data_q2[index][0]

# Normalizando JSON para DataFrame
data_q2 = json_normalize(data_q2)

# %%
# criando campo com data
data_q2["timestamp"] = data_q2["start_time"].map(lambda data: datetime.fromtimestamp(data/1000))
data_q2["dia_semana"] = data_q2["timestamp"].dt.weekday_name

# Visualizando a dispersão das taxas pelo tempo
plot_dispersao(df=data_q2, x='timestamp', y='request_counts')

# %%
# Preparando dataset
data_q2_modelo = data_q2[["timestamp", "request_counts"]].copy()
data_q2_modelo["dia_semana"] = data_q2["timestamp"].dt.weekday_name
data_q2_modelo["mes"] = data_q2["timestamp"].dt.month_name()
data_q2_modelo["hora"] = data_q2["timestamp"].dt.hour
data_q2_modelo["minuto"] = data_q2["timestamp"].dt.minute
data_q2_modelo["target"] = ["com_problema" if value < 0.40 else "sem_problema" for value in data_q2_modelo["request_counts"].values]

# Pivot das informações
pivot = pd.get_dummies(data_q2_modelo[["dia_semana","mes","hora","minuto"]].astype(str))
data_q2_modelo = pd.concat([data_q2_modelo, pivot], axis=1)

# Limpando dataset
data_q2_modelo.drop(["timestamp", "request_counts", "dia_semana", "mes", "hora", "minuto"], axis=1, inplace=True)
data_q2_modelo_y = data_q2_modelo[["target"]]
data_q2_modelo_x = data_q2_modelo.drop(["target"], axis=1)

# Analisando dispersao entre as classes no dataset original
print('Proporção das classes:\nSem Problema: {0}%\nCom problema:{1}%'.format(round(data_q2_modelo.target.value_counts()[0]/data_q2_modelo.shape[0], 3), 
                                                                             round(data_q2_modelo.target.value_counts()[1]/data_q2_modelo.shape[0], 3)))
# Out:
# Proporção das classes:
# Sem Problema: 0.98%
# Com problema:0.02%

# %%
# O dataset não é balanceado, vamos estratificar para manter a proporção
# 25% dos dados para avaliação
from sklearn.model_selection import StratifiedShuffleSplit
cv = StratifiedShuffleSplit(n_splits=1, test_size=0.30, random_state=10)

for indice_treino, indice_valid in cv.split(data_q2_modelo_x.values, data_q2_modelo_y.values):
    idx_treino, idx_valid = indice_treino, indice_valid

x_treino = data_q2_modelo_x.loc[idx_treino, :]
x_valid = data_q2_modelo_x.loc[idx_valid, :]

y_treino = data_q2_modelo_y.loc[idx_treino, :]
y_valid = data_q2_modelo_y.loc[idx_valid, :]

print("Proporção entre Treino e Validação")
print('Treino:\nSem Problema: {0}%\nCom problema:{1}%'.format(round(y_treino.target.value_counts()[0]/y_treino.shape[0], 3), 
                                                              round(y_treino.target.value_counts()[1]/y_treino.shape[0], 3)))

print('Validação:\nSem Problema: {0}%\nCom problema:{1}%'.format(round(y_valid.target.value_counts()[0]/y_valid.shape[0], 3), 
                                                                 round(y_valid.target.value_counts()[1]/y_valid.shape[0], 3)))
# Out:
# Proporção entre Treino e Validação
# Treino:
# Sem Problema: 0.98%
# Com problema:0.02%
# Validação:
# Sem Problema: 0.98%
# Com problema:0.02%

# %%
# Modelagem
from sklearn.metrics import recall_score, make_scorer
from sklearn.linear_model import LogisticRegression
import datetime

# Função de Tradução de variaveis categoricas para numericas
# Reference: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
# Description: Function created to translate categorical labels to numerical 
# to calculate True Positives, and the others, during the Classification tests (Confusion Matrix)
def recall_scoring(y_true, y_pred):
    return recall_score(y_true,y_pred, average="weighted")

# Função que busca maximizar Recall
# Reference: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html
scorer = make_scorer(recall_scoring, greater_is_better=True, needs_proba=False, needs_threshold=False)

# Modelo
# Vamos utilizar uma regressão logistica para fins de exemplo, devido ao tempo.
# Uma otimização do modelo poderia ser feita através do GridSearch, comparando 
# Parametros e etc, usando o grafico abaixo
modelo = LogisticRegression()

# Grafico que mostra a curva de aprendizado do modelo, através da validação cruzada
# mostrando os valores de Recall
# Por que Recall? 
# Precisamos garantir que quando aconteça uma falha, o modelo seja capaz de não perder o evento.
plot_learning_curve(estimator=modelo,  # Model
                    title="Regressão Logistica",      # Model Name
                    X=x_treino,        # Dataset features
                    y=y_treino,        # Dataset labels
                    ylim=(0.6, 1.01), # Plot y scale
                    cv=cv,            # Cross Validation 
                    n_jobs=-1)        # -1 = Using all CPUs

# Reduzindo tamanho do grafico
plt.rcParams.update({'figure.figsize': (5, 4)})
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:99: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# O Modelo apresenta uma taxa fixa de aprendizado tanto com base de treino, como com a validação cruzada
# para fins de exemplo, vamos continuar com a Regressão Logistica
# Treino final pós análise de aprendizado do modelo
from sklearn.metrics import confusion_matrix, classification_report
modelo.fit(x_treino, y_treino)

# Validação
predicoes = modelo.predict(x_valid)

# Matriz de Confusão
cnf_matrix = confusion_matrix(y_valid, predicoes)
np.set_printoptions(precision=2)
plt.figure()
plot_confusion_matrix(cnf_matrix, 
                      classes=modelo.classes_,
                      title='Confusion matrix, Normalized', 
                      normalize=False)
plt.rcParams.update({'figure.figsize': (5, 4)})
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Confusion matrix, without normalization

# %%
# Report com as métricas de cada Classe
print(classification_report(y_valid, predicoes))
# Out:
#               precision    recall  f1-score   support
#
# com_problema       0.27      0.07      0.11       138
# sem_problema       0.98      1.00      0.99      6671
#
#     accuracy                           0.98      6809
#    macro avg       0.63      0.53      0.55      6809
# weighted avg       0.97      0.98      0.97      6809

# %% [markdown]
# A ideia é buscar um modelo de classificação que consiga trabalhar bem com classes bem desbalanceadas, otimizar os parametros para cada cenário e encontrar o melhor modelo. Por conta de tempo, acredito ter passado a ideia sobre a minha solução.

# %% [markdown]
# ## Questão 3: Gestão de Mudança
# Um analista de AIOps está investigou um processo num sistema de TI e implementou um caso de uso com um modelo de regressão que atingia um coeficiente de determinação em torno de 0.75. O modelo implementado parecia estar funcionando bem na Operação por um tempo, dando resultados acurados o suficiente para tomada de decisões simples.
#
# No entanto, com o tempo, a performance do modelo começou a se degradar, e registrou um coeficiente de determinação bem menor, em torno de -2.26. O colega de equipe, sem entender muito bem o que pode estar acontecendo, pediu sua ajuda para analisar essa questão. Os dados coletados para analisar este problema foram disponibilizados no arquivo `process_change.csv`. O arquivo segue o formato abaixo:
#
# - `timestamp` é o timestamp do registro, no formato `[ano-mês-dia hora:minuto:segundo]`
# - `values` é o valor agregado ao referido processo.
#
# **Observação**:
# Sabe-se que em algum momento entre o mês de Janeiro e Março de 2020, houve uma alteração no processo (por conta de uma nova release) que está sendo monitorado que não foi comunicada previamente. Sabe-se também que não houve interrupção no processo de coleta nesse tempo.
#
# ### Perguntas
# - **(a)** O que pode ter acontecido com o modelo em questão para haver essa redução de efetividade?
# - **(b)** Como você evitaria que o problema acontecesse novamente?
# - **(c)** Qual é melhor forma que você considera para monitorar a qualidade do modelo a fim de evitar esse problema?
# - **(d)** Por favor, ilustre o processo sugerido no item c).

# %% [markdown]
# ### Respostas
# **(a)** O que pode ter acontecido com o modelo em questão para haver essa redução de efetividade?
#  -  Com o lançamento da nova release é possível que os dados coletados sofreram alguma alteração, o que resultou na queda de performance do modelo. Por exemplo, os dados disponibilizados nos mostram um campo de data e outro numérico, e dessa forma podemos inferir que essa alteração pode ter impactado na escala dos valores. Essas informações podem ser vista na celula abaixo, que nos mostra um gráfico de dispersão através do tempo. Nele é possível identificar que em um determinado momento do tempo (ao final do dia 16 para ser mais exato), os dados começam a retornar valores abaixo do comum e, em alguns momentos, chegando perto de zero (pós normalização).
#
# **(b)** Como você evitaria que o problema acontecesse novamente?
#  -  Caso o problema fosse de escala, o modelo precisaria receber dados normalizados, ou padronizados, além de monitorar o coeficiente para alertar caso seu valor comesse a ficar muito negativo, ou seja, adicionando um threshold de alerta. Se a coleta é feita online, entendo que o modelo é retreinado periodicamente. Adicionando esse threshold, caso a performance do modelo caia, podemos simplesmente não efetuar o deploy do modelo e enviar um alerta para os responsáveis.
#
# **(c)** Qual é melhor forma que você considera para monitorar a qualidade do modelo a fim de evitar esse problema?
#  -  Criar um processo automatizado que nos alerte quando o coeficiente do modelo estiver fora do que consideramos como uma margem segura de predição, criando um threshold, e não realizando o deploy do modelo.
#
# **(d)** Por favor, ilustre o processo sugerido no item c).
#  -

# %%
# Load dos dados
import pandas as pd

# Função de parser da data do arquivo csv
dateparse_q3 = lambda date: pd.datetime.strptime(date, '%Y-%m-%d %H:%M')

# load dos dados
# parse das datas em tempo de load do arquivo é mais rapido
data_q3 = pd.read_csv('datasets/process_change.csv', 
                   sep=',', 
                   header=0,
                   low_memory=False, 
                   encoding='utf-8',
                   parse_dates=['timestamp'], 
                   date_parser=dateparse_q3)

# %%
# código para questão 3-a:
from sklearn.preprocessing import MinMaxScaler
analise_normalizada = data_q3.copy()

# Criando objeto de normalização
scaler = MinMaxScaler()

# Treinando e normalizando os dados
scaler.fit(analise_normalizada["values"].values.reshape(-1, 1))
analise_normalizada["normalizado"] = scaler.transform(analise_normalizada["values"].values.reshape(-1, 1))

# Visualização
plot_dispersao(df=analise_normalizada, x='timestamp', y='normalizado')

# %%
# código para questão 3:
# Vou treinar um modelo para exemplificar o monitoramento, sem considerar a abertura dos dados e etc
from sklearn.externals import joblib

# Reta de Corte
threshold = -5

# Separando features de Target
x_treino = data_q3[["timestamp"]]
y_treino = data_q3["values"]

# Criando um modelo com base nos dados "coletados"
modelo_q3 = LinearRegression(normalize=True, n_jobs=-1).fit(x_treino.values.reshape(-1, 1), y_treino.values.reshape(-1, 1))

# Carregando os coeficientes em formato de tupla
coeficientes = []
for indice, coluna in enumerate(x_treino.columns):
  if modelo_q3.coef_[0][indice] > threshold:
    coeficientes.append((coluna, modelo_q3.coef_[0][indice]))

# Exibindo a mensage, com quebra de linha por cada coluna
mensagem = ["Modelo apresenta um coeficiente de determinação não suficiente para deploy em produção."]
if coeficientes:
  for coluna, coef in coeficientes:
    mensagem.append("Coluna: {0} - Coeficiente: {1}".format(coluna, coef))
  print('\n'.join(mensagem))
else:
  print("Threshold atingido. Seguindo com deploy...")
  joblib.dump(modelo_q3, "/modelos/modelo_regressao.bin")
# Out:
# Modelo apresenta um coeficiente de determinação não suficiente para deploy em produção.
# Coluna: timestamp - Coeficiente: -6.372019311066602e-16
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Questão 4: Más práticas de engenharia de software
# É comum observarmos código mal-escrito no mercado de dados. Abaixo você encontrará alguns excertos de código ineficiente ou problemático. Como você os corrigiria ou os otimizaria?

# %% [markdown]
# - **a)** O código abaixo refere-se ao cálculo da sequência de fibonacci. Como você pode observar com o resultado da análise de runtime, essa função é bem ineficiente, demorando 32 segundos para calcular 40 números da sequência. De que forma ele poderia ser otimizado para que responda mais rapidamente?

# %%
# por favor não mexa nessa célula:
# questão 4, item a):
def fibonacci(n):
    if n in [0, 1]:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

n = 40

# Atenção: se você rodar essa célula novamente vai demorar bastante!
# %timeit -r1 -n1 fibonacci(n)
# Out:
# 1 loop, best of 1: 40.2 s per loop

# %%
# questão 4, resposta para item a)
# Ao inves de usar recursividade, que possui um custo computacional altissímo, podemos usar um laço classico para diminuir o processamento computacional
def fibonacci_duan(valor):
    anterior = 0
    atual = 1
    for value in range(valor):
        anterior, atual = anterior+atual, anterior
    return anterior

n = 40

# %timeit -r1 -n1 fibonacci_duan(n)
# Out:
# 1 loop, best of 1: 7.65 µs per loop

# %% [markdown]
# - **b)** O código abaixo refere-se a tentar inicializar uma varíavel numa dataframe pandas. No entanto, como pode observar, demora pouco mais de 1 segundo para importar um arquivo de 100 MB e quanto maior o arquivo, mais tempo demora. De que forma esse código poderia ser otimizado para carregar mais rápido o arquivo?

# %%
# questão 4, item b):
import pandas as pd

# %timeit -r1 -n1 pd.read_csv('./datasets/access.log', sep='\t')
# Out:
# 1 loop, best of 1: 1.69 s per loop

# %%
# com chunksize, que limita a leitura do arquivo e cria um iteravel para acessar os dados
# questão 4, resposta para item b)

# %timeit -r1 -n1 pd.read_csv('./datasets/access.log', sep='\t', chunksize=500000)
# Out:
# 1 loop, best of 1: 4.28 ms per loop

# %% [markdown]
# - **c)** O código abaixo reflete uma situação comum num cenário de dados: carregar um arquivo grande demais para a memória do computador. De que forma poderíamos realizar a operação em questão sem ter problemas de memória?

# %%
# %%timeit -r1 -n1
# questão 4, item c):
import pandas as pd
import numpy as np

# imagine que o arquivo em questão é bem maior (cerca de 16 GB)
logs = pd.read_csv('./datasets/access.log',sep='\t', 
                 names=['TIMESTAMP','RESPONSE_TIME'])
logs['TIMESTAMP'] = pd.to_datetime(logs['TIMESTAMP'], unit='s')
logs = logs.sort_values(by='TIMESTAMP')
logs = logs.set_index('TIMESTAMP')

# calculando operações 
# Define the features you'll calculate for each window
rolling_logs = logs.rolling(20, min_periods=5, closed='right')
to_calculate = [np.min, np.max, np.mean, np.std]
features = rolling_logs.aggregate(to_calculate)
# Out:
# 1 loop, best of 1: 5.96 s per loop

# %%
# questão 4, resposta para item c)
# %%timeit -r1 -n1
# questão 4, item c):
import pandas as pd
import numpy as np
from datetime import datetime

# imagine que o arquivo em questão é bem maior (cerca de 16 GB)
# vamos utilizar chunks, para limitar a quantidade de leitura do arquivo
logs = pd.read_csv('./datasets/access.log',
                   sep='\t', 
                   names=['TIMESTAMP','RESPONSE_TIME'],
                   chunksize=50000)

# Cria uma lista com todos os chunks e apaga a lista da memoria no final
logs = pd.concat([data for data in logs])

# Processamento
logs['TIMESTAMP'] = pd.to_datetime(logs['TIMESTAMP'], unit='s')
logs = logs.sort_values(by='TIMESTAMP')
logs = logs.set_index('TIMESTAMP')

# calculando operações 
# Define the features you'll calculate for each window
rolling_logs = logs.rolling(20, min_periods=5, closed='right')
to_calculate = [np.min, np.max, np.mean, np.std]
features = rolling_logs.aggregate(to_calculate)
# Out:
# 1 loop, best of 1: 8.09 s per loop

# %% [markdown]
# ## Sugestões:
# - Pensem nesse notebook como a apresentação da sua abordagem quanto a um problema do dia-a-dia a um(a) colega de trabalho. Seria ótimo se o código e as respostas estivessem bem documentadas, certo? Nomes de variáveis, estrutura das classes ou funções, docstrings, tudo isso é bastante importante para o trabalho em equipe e compartilhamento de conhecimento, duas coisas que valorizamos muito na área de AIOps;
# - Leiam com atenção a seção de **Contexto dos clientes internos e usuários** e pensem em como melhor comunicar os resultados tendo em conta, por exemplo, o grupo usuário final do insight gerado.
# - Não se limitem a forma de apresentação das respostas. Usem imagens, desenhos, gifs, gráficos. Demonstrem seu raciocínio da forma que acharem mais esclarecedora;
# - Se não souberem de algum tema específico colocado aqui (por exemplo, o que são logs Weblogic), façam as devidas pesquisas de referência na internet. A não ser que seja uma informação estritamente pecular à Vivo ou à equipe de AIOps, informações quanto ao conteúdo abordado não serão descritas;
#
# ## Contatos:
# - Para dúvidas em relação ao desafio ou submissão das respostas, contatar Mateus Gomes no e-mail mateus.pgomes@telefonica.com;
# - Para dúvidas em relação à vaga e a próximos passos, contatar Lívia Oliveira no e-mail liviam.oliveira@telefonica.com;

# %% [markdown]
# ## Referências
# As referências devem ser colocadas no formato: Autor, Título, Url de acesso. Em caso de livros, apenas Autor, Título e Edição serão suficientes.
#
# Exemplo:
# - [**Elastic.co**, *Documentação do agente Metricbeat*, https://www.elastic.co/guide/en/beats/metricbeat/current/exported-fields-system.html](https://www.elastic.co/guide/en/beats/metricbeat/current/exported-fields-system.html)
#
# Refêrencia utilizadas:
# - [**Duan Github**, *Repositórios*, https://github.com/duanpsycho](https://github.com/duanpsycho)
#
#
# - [**Vernier**, *What are Mean Squared Error and Root Mean Squared Error?*, https://www.vernier.com/til/1014](https://www.vernier.com/til/1014)
#
# - [**Matplotlib**, *Documentação da Biblioteca Matplotlib para Python*, https://matplotlib.org/gallery/mplot3d/mixed_subplots.html?highlight=figure%20figsize](https://matplotlib.org/gallery/mplot3d/mixed_subplots.html?highlight=figure%20figsize)
#
# - [**scikit-learn.org**, *sklearn.model_selection.KFold*, https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold)
#
# - [**scikit-learn.org**, *sklearn.linear_model.LinearRegression*, https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linearregression#sklearn.linear_model.LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linearregression#sklearn.linear_model.LinearRegression)
#
# - [**scikit-learn.org**, *sklearn.metrics.mean_squared_error*, https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)
#
# - [**scikit-learn.org**, *Plotting Learning Curves*, https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html](https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html)
#
# - [**scikit-learn.org**, *Confusion matrix*, https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html](https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html)
#
# - [**scikit-learn.org**, *sklearn.linear_model.LogisticRegression*, https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)
#
# - [**scikit-learn.org**, *sklearn.metrics.recall_score*, https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score)
#
# - [**scikit-learn.org**, *sklearn.model_selection.StratifiedShuffleSplit*, https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html?highlight=stratified#sklearn.model_selection.StratifiedShuffleSplit](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html?highlight=stratified#sklearn.model_selection.StratifiedShuffleSplit)
#
# - [**scikit-learn.org**, *sklearn.preprocessing.MinMaxScaler*, https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler)
#
# - [**Duan, Ariel, Juliana e Jenifer**, *Análise de Sentimento para Reviews de Filmes, em Português*, https://github.com/duanpsycho/FIAP-2IA-TrabalhoFinalNLP/blob/master/FIAP-NLP-Analise_de_Sentimentos.ipynb](https://github.com/duanpsycho/FIAP-2IA-TrabalhoFinalNLP/blob/master/FIAP-NLP-Analise_de_Sentimentos.ipynb)
#
# - [**Duan, Ariel, Juliana e Jenifer**, *Projeto Final: Estimando Preços de Automóveis Utilizando Modelos de Regressão*, https://github.com/duanpsycho/FIAP-2IA-TrabalhoFinalPython/blob/master/FIAP-automobile-price-prediction_final.ipynb](https://github.com/duanpsycho/FIAP-2IA-TrabalhoFinalPython/blob/master/FIAP-automobile-price-prediction_final.ipynb)
#
# - [**pandas.pydata.org**, *API reference*, https://pandas.pydata.org/pandas-docs/stable/reference/index.html](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)
#
# - [**Epoch Converter by Misja.com**, *Epoch & Unix Timestamp Conversion Tools*, https://www.epochconverter.com/](https://www.epochconverter.com/)
